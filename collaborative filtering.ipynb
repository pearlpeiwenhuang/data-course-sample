# %% [markdown]
# # Sample Code

# %%
# !apt-get -y install openjdk-8-jre-headless
# !pip install pyspark
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Suggested packages:
#   libnss-mdns fonts-dejavu-extra fonts-ipafont-gothic fonts-ipafont-mincho
#   fonts-wqy-microhei fonts-wqy-zenhei fonts-indic
# The following NEW packages will be installed:
#   openjdk-8-jre-headless
# 0 upgraded, 1 newly installed, 0 to remove and 37 not upgraded.
# Need to get 28.2 MB of archives.
# After this operation, 104 MB of additional disk space will be used.
# Ign:1 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u292-b10-0ubuntu1~18.04
# Err:1 http://security.ubuntu.com/ubuntu bionic-updates/universe amd64 openjdk-8-jre-headless amd64 8u292-b10-0ubuntu1~18.04
#   404  Not Found [IP: 91.189.88.142 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jre-headless_8u292-b10-0ubuntu1~18.04_amd64.deb  404  Not Found [IP: 91.189.88.142 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?
# Collecting pyspark
#   Downloading pyspark-3.2.0.tar.gz (281.3 MB)
#      |████████████████████████████████| 281.3 MB 34 kB/s
# Collecting py4j==0.10.9.2
#   Downloading py4j-0.10.9.2-py2.py3-none-any.whl (198 kB)
#      |████████████████████████████████| 198 kB 45.0 MB/s
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-3.2.0-py2.py3-none-any.whl size=281805912 sha256=6797cfb0f4d5294da64d1fcdb63243227c4b196adc36f4b4f44ac76ebaee7c89
#   Stored in directory: /root/.cache/pip/wheels/0b/de/d2/9be5d59d7331c6c2a7c1b6d1a4f463ce107332b1ecd4e80718
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
# Successfully installed py4j-0.10.9.2 pyspark-3.2.0

# %%
from pyspark.sql import SparkSession, DataFrame, Window
from pyspark.sql.functions import col, regexp_extract, regexp_replace, lit, when
import pyspark.sql.functions as func
from pyspark.sql.types import *
from pyspark.sql.utils import AnalysisException
from pyspark import StorageLevel

import sys
from datetime import datetime, timedelta
from functools import reduce
from itertools import chain

# %%
spark = SparkSession.builder \
    .appName("content-based") \
    .config("spark.sql.files.ignoreCorruptFiles", "true") \
    .config("spark.sql.session.timeZone", "Asia/Taipei") \
    .getOrCreate()

# %% [markdown]
# ## 基礎建設

# %%
import pandas as pd
import gzip, json
import re

def parse(path):
    g = gzip.open(path, 'rb')
    for l in g:
        yield json.loads(l)

def getDF(path):
    i = 0
    df = {}
    for d in parse(path):
        df[i] = d
        i += 1
    return pd.DataFrame.from_dict(df, orient='index')

# %% [markdown]
# ## 載入資料

# %%
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# !wget http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Out:
# --2022-01-04 09:11:17--  http://deepyeti.ucsd.edu/jianmo/amazon/categoryFilesSmall/All_Beauty.csv
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15499476 (15M) [application/octet-stream]
# Saving to: ‘All_Beauty.csv’
#
# All_Beauty.csv      100%[===================>]  14.78M  73.6MB/s    in 0.2s
#
# 2022-01-04 09:11:17 (73.6 MB/s) - ‘All_Beauty.csv’ saved [15499476/15499476]
#
# --2022-01-04 09:11:17--  http://deepyeti.ucsd.edu/jianmo/amazon/metaFiles2/meta_All_Beauty.json.gz
# Resolving deepyeti.ucsd.edu (deepyeti.ucsd.edu)... 169.228.63.50
# Connecting to deepyeti.ucsd.edu (deepyeti.ucsd.edu)|169.228.63.50|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10329961 (9.9M) [application/octet-stream]
# Saving to: ‘meta_All_Beauty.json.gz’
#
# meta_All_Beauty.jso 100%[===================>]   9.85M  61.1MB/s    in 0.2s
#
# 2022-01-04 09:11:18 (61.1 MB/s) - ‘meta_All_Beauty.json.gz’ saved [10329961/10329961]

# %%
# schema_rating = StructType([
#                     StructField("asin", StringType())
#                       , StructField("reviewerID", StringType())
#                       , StructField("overall", StringType())
#                       , StructField("unixReviewTime", StringType())
#                       ])

metadata = spark.read.json("file:////content/meta_All_Beauty.json.gz")
# ratings = spark.read.format("csv").option("header", True).schema(schema_rating).load("file:///content/All_Beauty.csv")

# metadata = getDF('/content/meta_All_Beauty.json.gz')
ratings = pd.read_csv('/content/All_Beauty.csv', names=['asin', 'reviewerID', 'overall', 'unixReviewTime'], header=None)
# metadata.head()
# ratings.head()

# %% [markdown]
# ## 資料整理

# %%
metadata = metadata.select(
                col("asin")
                , col("title")
                , func.when(col("title") == '', 0).otherwise(1).alias("if_title")
                , col("feature")
                , func.when(func.size("feature") == 0, 0).otherwise(1).alias("if_feature")
                , col("description")
                , func.when(func.size("description") == 0, 0).otherwise(1).alias("if_description")
                , func.translate(col("price"), ',$', '').cast(DoubleType()).alias("price")
                , col("imageURL"), col("imageURLHighRes")
                , func.when(func.size("imageURL") == 0, 0).otherwise(1).alias("if_imageURL")
                , func.when(func.size("imageURLHighRes") == 0, 0).otherwise(1).alias("if_imageURLHighRes")
                , col("also_buy"), col("also_view")
                , func.translate(func.split(col("rank"), ' in ')[0], ',', '').cast(IntegerType()).alias("rank_sub_category")
                , func.translate(func.split(col("rank"), ' in ')[1], '()"];', '').alias("sub_category")
                , col("brand")
                , col("tech1")
                , func.when(func.length("tech1") == 0, 0).otherwise(1).alias("if_tech1")
                , col("similar_item"), col("date")
                , col("details.\n    Item Weight: \n    ").alias("item_weight")
                , col("details.\n    Product Dimensions: \n    ").alias("product_dimensions")
                , col("details.Batteries").alias("batteries")
                , func.when(col("details.Batteries").isNull(), 0).otherwise(1).alias("if_batteries")
                , col("details.Discontinued by manufacturer:").alias("discountedByManufacturer")
                , func.when(col("details.Discontinued by manufacturer:").isNull(), 0).otherwise(1).alias("if_discountedByManufacturer")
                , col("details.Domestic Shipping: ").alias("domestic_shipping")
                , col("details.International Shipping: ").alias("international_shipping")
                , col("details.Item model number:").alias("item_model_no")
                , col("details.Shipping Advisory:").alias("shipping_advisory")
                , col("details.Shipping Weight:").alias("shipping_weight")
                )

# %%
metadata.describe().show()
# Out:
# +-------+-------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+
# |summary|               asin|               title|            if_title|         if_feature|     if_description|             price|       if_imageURL|if_imageURLHighRes|rank_sub_category| sub_category|   brand|               tech1|            if_tech1|        similar_item|                date|item_weight|  product_dimensions|           batteries|        if_batteries|discountedByManufacturer|if_discountedByManufacturer|   domestic_shipping|international_shipping|item_model_no|   shipping_advisory|shipping_weight|
# +-------+-------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+
# |  count|              32892|               32892|               32892|              32892|              32892|             11270|             32892|             32892|            32452|        32515|   32892|               32892|               32892|               32892|               32892|       3523|                5303|                  90|               32892|                     292|                      32892|                1387|                  1387|         5600|                   7|          20032|
# |   mean|8.525224324631579E9|           658469.21|  0.9999695974705095|0.00817828043293202|0.45965584336616805|28.100208518189003|0.5028882403015931|0.5028882403015931|1288189.878743991|         null|Infinity|                null|3.040252949045360...|                null|                null|       null|                null|                null|0.002736227654140...|                    null|       0.008877538611212453|                null|                  null|     Infinity|                null|           null|
# | stddev|1.088695684419192E9|  1975384.4212928389|0.005513848881720793|0.09006465886545666| 0.4983772671408194| 54.10751501714149|0.4999992586772454|0.4999992586772454|815171.4356748629|         null|     NaN|                null| 0.01743393541726527|                null|                null|       null|                null|                null| 0.05223814387502486|                    null|        0.09380296067362129|                null|                  null|          NaN|                null|           null|
# |    min|         6546546450|                    |                   0|                  0|                  0|              0.01|                 0|                 0|               35|  Automotive |        |                    |                   0|                    |                    |0.16 ounces|0.1 x 0.1 x 0.1 i...|1 12V batteries r...|                   0|                     Yes|                          0|Amazon only ships...|  This item can be ...|         # 35|This item must be...|     0.2 ounces|
# |    max|         B01HJEGTYK|~5 Pack~covergirl...|                   1|                  1|                  1|            2149.0|                 1|                 1|          9549407|Toys & Games |  zonman| class="a-keyvalu...|                   1| class="a-bordere...|Wedding Hair Acce...|9.95 pounds|97 x 20 x 20 inch...|Lithium Metal bat...|                   1|                     Yes|                          1|This item can onl...|  This item is not ...|         zy80|This item must be...|    99 pounds (|
# +-------+-------------------+--------------------+--------------------+-------------------+-------------------+------------------+------------------+------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+

# %%
metadata = metadata.select(col("*"), when(col("sub_category") == 'Beauty & Personal Care ', 'Beauty & Personal Care')
                  .when(col("sub_category") == 'Beauty & Personal Care See Top 100', 'Beauty & Personal Care')
                  .when(col("sub_category") == 'Beauty & Personal Care See top 100', 'Beauty & Personal Care')
                  .when(col("sub_category") == 'Beauty &amp Personal Care ', 'Beauty & Personal Care')
                  .when(col("sub_category") == 'Beauty &amp Personal Care', 'Beauty & Personal Care')
                  .when(col("sub_category") == 'Grocery & Gourmet Food ', 'Grocery & Gourmet Food')
                  .when(col("sub_category") == 'Grocery & Gourmet Food See Top 100', 'Grocery & Gourmet Food')
                  .when(col("sub_category") == 'Grocery &amp Gourmet Food ', 'Grocery & Gourmet Food')
                  .when(col("sub_category") == 'Health & Household ', 'Health & Household')
                  .when(col("sub_category") == 'Health &amp Household ', 'Health & Household')
                  .when(col("sub_category").isNull(), 'no Category')
                  .otherwise(col("sub_category")).alias("subcategory")
                  , when(col("brand") == '', 'no Category')
                  .when(col("brand") == '*', 'no Category')
                  .when(col("brand") == '-', 'no Category')
                  .when(col("brand") == '....', 'no Category')
                  .when(col("brand") == '.......', 'no Category')
                  .when(col("brand") == '.........', 'no Category')
                  .when(col("brand").isNull(), 'no Category')
                  .otherwise(col("brand")).alias("brand_preprocessed")
                  , when((col("price") >= 0.01) & (col("price") < 8.99), 'first')
                  .when((col("price") >= 8.99) & (col("price") < 15.99), 'second')
                  .when((col("price") >= 15.99) & (col("price") < 29.99), 'avg')
                  .when((col("price") >= 29.99) & (col("price") < 200.00), 'fourth')
                  .when((col("price") >= 200.00) & (col("price") < 2150.0), 'luxury')
                  .otherwise('abnormal').alias("price_range"))

# %%
# if the info on below variables are not null, then sum as 1
# log10 rank by sub_category and multiply 100 as score
metadata_scored = metadata.withColumn('score_if', func.sum(col("if_title")+col("if_feature")+col("if_description")+col("if_imageURL") \
                                      +col("if_imageURLHighRes")+col("if_tech1")+col("if_batteries") \
                                      +col("if_discountedByManufacturer")).over(Window.partitionBy("asin"))) \
                          .withColumn('score_rank', (100 / func.log10(col("rank_sub_category"))).alias("score_rank")) \
                          .withColumn('product_score', col("score_if") + col("score_rank"))

# %%
metadata_scored.describe().show()
# Out:
# +-------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+-------------------+-------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+-----------+------------------+-----------+------------------+------------------+------------------+
# |summary|                asin|               title|            if_title|         if_feature|     if_description|             price|        if_imageURL| if_imageURLHighRes|rank_sub_category| sub_category|   brand|               tech1|            if_tech1|        similar_item|                date|item_weight|  product_dimensions|           batteries|        if_batteries|discountedByManufacturer|if_discountedByManufacturer|   domestic_shipping|international_shipping|item_model_no|   shipping_advisory|shipping_weight|subcategory|brand_preprocessed|price_range|          score_if|        score_rank|     product_score|
# +-------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+-------------------+-------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+-----------+------------------+-----------+------------------+------------------+------------------+
# |  count|               32892|               32892|               32892|              32892|              32892|             11270|              32892|              32892|            32452|        32515|   32892|               32892|               32892|               32892|               32892|       3523|                5303|                  90|               32892|                     292|                      32892|                1387|                  1387|         5600|                   7|          20032|      32892|             32892|      32892|             32892|             32452|             32452|
# |   mean| 8.525224324631579E9|           658469.21|  0.9999695974705095|0.00817828043293202|0.45965584336616805|28.100208518190037| 0.5028882403015931| 0.5028882403015931|1288189.878743991|         null|Infinity|                null|3.040252949045360...|                null|                null|       null|                null|                null|0.002736227654140...|                    null|       0.008877538611212453|                null|                  null|     Infinity|                null|           null|       null|          Infinity|       null| 2.554511735376383| 16.77675731440375|19.327046972976476|
# | stddev|1.0886956844191914E9|   1975384.421292839|0.005513848881720789|0.09006465886545667|0.49837726714081937| 54.10751501714152|0.49999925867724543|0.49999925867724543|815171.4356748699|         null|     NaN|                null| 0.01743393541726531|                null|                null|       null|                null|                null| 0.05223814387502503|                    null|        0.09380296067362141|                null|                  null|          NaN|                null|           null|       null|               NaN|       null|1.2555947636105356|1.3191334707123241|1.9722009771916345|
# |    min|          6546546450|                    |                   0|                  0|                  0|              0.01|                  0|                  0|               35|  Automotive |        |                    |                   0|                    |                    |0.16 ounces|0.1 x 0.1 x 0.1 i...|1 12V batteries r...|                   0|                     Yes|                          0|Amazon only ships...|  This item can be ...|         # 35|This item must be...|     0.2 ounces|Automotive |         #Flashmob|   abnormal|                 1|14.326695996994003|16.286408057528053|
# |    max|          B01HJEGTYK|~5 Pack~covergirl...|                   1|                  1|                  1|            2149.0|                  1|                  1|          9549407|Toys & Games |  zonman| class="a-keyvalu...|                   1| class="a-bordere...|Wedding Hair Acce...|9.95 pounds|97 x 20 x 20 inch...|Lithium Metal bat...|                   1|                     Yes|                          1|This item can onl...|  This item is not ...|         zy80|This item must be...|    99 pounds (|no Category|            zonman|     second|                12|  64.7639852180729|  68.7639852180729|
# +-------+--------------------+--------------------+--------------------+-------------------+-------------------+------------------+-------------------+-------------------+-----------------+-------------+--------+--------------------+--------------------+--------------------+--------------------+-----------+--------------------+--------------------+--------------------+------------------------+---------------------------+--------------------+----------------------+-------------+--------------------+---------------+-----------+------------------+-----------+------------------+------------------+------------------+

# %%
# metadata.stat.corr("rank_sub_category", "score_if")
# metadata_scored.summary().show(10, False)
metadata_selected = metadata_scored.select("asin", "title", "description", "brand_preprocessed", "rank_sub_category", "subcategory", "price", "price_range", "score_rank", "score_if")
metadata_selected.summary().show(10, False)
# Out:
# +-------+--------------------+---------------------------------------------------------------------+------------------+-----------------+-----------+------------------+-----------+------------------+-----------------+
# |summary|asin                |title                                                                |brand_preprocessed|rank_sub_category|subcategory|price             |price_range|score_rank        |score_if         |
# +-------+--------------------+---------------------------------------------------------------------+------------------+-----------------+-----------+------------------+-----------+------------------+-----------------+
# |count  |32892               |32892                                                                |32892             |32452            |32892      |11270             |32892      |32452             |32892            |
# |mean   |8.525224324631579E9 |658469.21                                                            |Infinity          |1288189.878743991|null       |28.100208518190037|null       |16.776757314403728|2.554511735376383|
# |stddev |1.0886956844191914E9|1975384.421292839                                                    |NaN               |815171.4356748682|null       |54.107515017141495|null       |1.3191334707123115|1.255594763610534|
# |min    |6546546450          |                                                                     |#Flashmob         |35               |Automotive |0.01              |abnormal   |14.326695996994003|1                |
# |25%    |7.41420479E9        |2.0                                                                  |-417.0            |677360           |null       |8.99              |null       |16.017062152481223|2                |
# |50%    |8.867326759E9       |2.0                                                                  |1907.0            |1133278          |null       |15.99             |null       |16.516812790003573|3                |
# |75%    |9.623402791E9       |7.0                                                                  |Infinity          |1750630          |null       |29.99             |null       |17.14959358710001 |3                |
# |max    |B01HJEGTYK          |~5 Pack~covergirl Outlast All Day Two Step Lipcolor, Forever Fawn 598|zonman            |9549407          |no Category|2149.0            |second     |64.7639852180729  |12               |
# +-------+--------------------+---------------------------------------------------------------------+------------------+-----------------+-----------+------------------+-----------+------------------+-----------------+

# %%
metadata_pd = metadata_selected.toPandas()

# %%
metadata_pd['score_rank'].fillna(99, inplace=True)
metadata_pd['score_if'].fillna(1, inplace=True)

# %%
metadata_pd.head(2)
# Out:
#          asin  ... score_if
# 0  6546546450  ...        2
# 1  7178680776  ...        2
#
# [2 rows x 10 columns]

# %%
# replace [] on description by ''
metadata_pd['description'] = metadata_pd['description'].apply(lambda x: ' '.join(x))
# combine description, title, brand and subcategory (from rank)
metadata_pd['unstructured'] = metadata_pd['title'] + ' ' + metadata_pd['brand_preprocessed'] + ' ' + metadata_pd['description'] + ' ' + metadata_pd['subcategory']
# # remove special characters besides numbers
# metadata_pd['unstructured'] = metadata_pd['unstructured'].apply(lambda x: re.sub(r"(?<!\d)[\W](?!\d)", ' ', str(x)))
# # to lowercase
# metadata_pd['unstructured'] = metadata_pd['unstructured'].str.lower()

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
# from nltk.corpus import words #text = words.words()

REPLACE_BY_SPACE_RE = re.compile('[/(){}\[\]\|@,;]')
BAD_SYMBOLS_RE = re.compile('[^0-9a-z #+_]')
STOPWORDS = set(stopwords.words('english'))

def clean_text(text):
    """
        text: a string
        
        return: modified initial string
    """
    text = text.lower() # lowercase text
    text = REPLACE_BY_SPACE_RE.sub(' ', text) # replace REPLACE_BY_SPACE_RE symbols by space in text. substitute the matched string in REPLACE_BY_SPACE_RE with space.
    text = BAD_SYMBOLS_RE.sub('', text) # remove symbols which are in BAD_SYMBOLS_RE from text. substitute the matched string in BAD_SYMBOLS_RE with nothing. 
    text = ' '.join(word for word in text.split() if word not in STOPWORDS) # remove stopwors from text
    
    return text
    
metadata_pd['unstructured'] = metadata_pd['unstructured'].apply(clean_text)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
metadata_pd.describe()
# Out:
#        rank_sub_category         price    score_rank      score_if
# count       3.245200e+04  11270.000000  32892.000000  32892.000000
# mean        1.288190e+06     28.100209     17.876667      2.554512
# std         8.151714e+05     54.107515      9.536660      1.255595
# min         3.500000e+01      0.010000     14.326696      1.000000
# 25%         6.775218e+05      8.990000     16.023486      2.000000
# 50%         1.133461e+06     15.990000     16.531682      3.000000
# 75%         1.751104e+06     29.990000     17.184865      3.000000
# max         9.549407e+06   2149.000000     99.000000     12.000000

# %%
metadata_pd.sample()
# Out:
#              asin  ...                                       unstructured
# 28589  B016BD42JY  ...  lookatoolreg newly sauna slimming belt waist w...
#
# [1 rows x 11 columns]

# %%
metadata_pd = metadata_pd.drop(columns=['title', 'description', 'rank_sub_category', 'price'])
metadata_pd.head(5)
# Out:
#          asin  ...                                       unstructured
# 0  6546546450  ...  loud n cleartrade personal sound amplifier ide...
# 1  7178680776  ...  no7 lift amp luminate triple action serum 50ml...
# 2  7250468162  ...  no7 stay perfect foundation cool vanilla no7 n...
# 3  7367905066  ...  wella koleston perfect hair colour 44 44 mediu...
# 4  7414204790  ...  lacto calamine skin balance oil control 120 ml...
#
# [5 rows x 7 columns]

# %%
metadata_pd.info()
metadata_pd.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32892 entries, 0 to 32891
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   asin                32892 non-null  object
#  1   brand_preprocessed  32892 non-null  object
#  2   subcategory         32892 non-null  object
#  3   price_range         32892 non-null  object
#  4   score_rank          32892 non-null  float64
#  5   score_if            32892 non-null  int64
#  6   unstructured        32892 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 1.8+ MB
# asin                  32488
# brand_preprocessed     7858
# subcategory              11
# price_range               6
# score_rank            31878
# score_if                  9
# unstructured          32335
# dtype: int64

# %%
categorical_cols = ['brand_preprocessed', 'subcategory', 'price_range', 'score_if'] #score_rank
metadata_one_hot = pd.get_dummies(metadata_pd, columns = categorical_cols)

# %%
ratings['DATE'] = pd.to_datetime(ratings['unixReviewTime'], unit='s')

# %% [markdown]
# ## 資料切分

# %%
# only extract past 3 months data for training because beauty product is seasonal
ratings_trainings = ratings[
    (ratings['DATE'] >= '2018-06-01') & (ratings['DATE'] < '2018-09-01')
]
ratings_testings = ratings[
    (ratings['DATE'] >= '2018-09-01') & 
    (ratings['DATE'] <= '2018-09-30')
]
ratings_testings_by_user = ratings_testings.groupby('reviewerID').agg(list).reset_index()[['reviewerID', 'asin']].to_dict('records')
ratings_testings_by_user = { rating['reviewerID']: rating['asin'] for rating in ratings_testings_by_user }
users = list(ratings_testings_by_user.keys())

# %%
# product_popularity
rating_product_popularity = pd.DataFrame(ratings_trainings.asin.value_counts())
rating_product_popularity.reset_index(inplace=True)
rating_product_popularity.columns = ['asin', 'count']
# avg review
ratings_avg_overall = ratings_trainings.groupby('asin', as_index = False)['overall'].mean()
# join above rating summary
rating_asin = pd.merge(rating_product_popularity,ratings_avg_overall,on='asin',how='inner')

# %%
rating_asin.info()
rating_asin.nunique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2475 entries, 0 to 2474
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   asin     2475 non-null   object
#  1   count    2475 non-null   int64
#  2   overall  2475 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 77.3+ KB
# asin       2475
# count        46
# overall     136
# dtype: int64

# %%
ratings_metadata_one_hot = pd.merge(rating_asin,metadata_one_hot,on='asin',how='inner')

# %%
ratings_metadata = pd.merge(rating_asin,metadata_pd,on='asin',how='inner')

# %%
# rule-based variables
# ratings_metadata['brand_loyalty'] = ratings_metadata.groupby(["reviewerID", "brand_filled"])["asin"].transform('count')
# ratings_metadata['brand_loyalty'].fillna(1, inplace=True)
# ratings_metadata['subcategory_loyalty'] = ratings_metadata.groupby(["reviewerID", "subcategory"])["asin"].transform('count')
# ratings_metadata['subcategory_loyalty'].fillna(1, inplace=True)
# ratings_metadata['avg_brandLoyalty'] = ratings_metadata.groupby(["asin"])["brand_loyalty"].transform('mean')
# ratings_metadata.head(2)

# %%
ratings_metadata.head(2)
# Out:
#          asin  ...                                       unstructured
# 0  B01DKQAXC0  ...  bali secrets natural deodorant organic amp veg...
# 1  B00W259T7G  ...  pre de provence artisanal french soap bar enri...
#
# [2 rows x 9 columns]

# %%
ratings_metadata_one_hot = ratings_metadata_one_hot.drop(columns=['count', 'overall', 'score_rank', 'unstructured'])

# %%
ratings_metadata_one_hot.sample()
# Out:
#             asin  brand_preprocessed_#Flashmob  ...  score_if_10  score_if_12
# 1370  B00H4HCHRG                             0  ...            0            0
#
# [1 rows x 7885 columns]

# %% [markdown]
# **EDA**

# %%
# from sklearn.metrics.pairwise import linear_kernel
from sklearn.feature_extraction.text import CountVectorizer

# %% [markdown]
# Token Frequency Distribution Removing Stop Words

# %%
def unusual_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0)
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    df0 = pd.DataFrame(words_freq, columns = ['unstructured' , 'count'])
    text_vocab = set(w.lower() for w in df0['unstructured'] if w.isalpha())
    english_vocab = set(w.lower() for w in nltk.corpus.words.words())
    unusual = text_vocab - english_vocab
    unusual = sorted(unusual)
    # words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    # words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return unusual[:n]

# %%
# find out unusual words
from nltk.corpus import words
nltk.download('words')

vec = CountVectorizer().fit(ratings_metadata['unstructured'])
bag_of_words = vec.transform(ratings_metadata['unstructured'])
sum_words = bag_of_words.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
df0 = pd.DataFrame(words_freq, columns = ['unstructured' , 'count'])
text_vocab = set(w.lower() for w in df0['unstructured'] if w.isalpha())
english_vocab = set(w.lower() for w in nltk.corpus.words.words())
unusual = text_vocab - english_vocab
unusual = sorted(unusual)
print(unusual)
# Out:
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Unzipping corpora/words.zip.
# ['aaa', 'aaatssox', 'aacute', 'aamp', 'abbott', 'abbotts', 'abilities', 'abounds', 'abrasionbr', 'abrasions', 'abrasiveness', 'abrasives', 'abs', 'absolutes', 'absorbs', 'ac', 'acai', 'accelerates', 'accelerating', 'accelerators', 'accented', 'accentuates', 'acceptbr', 'accesory', 'accessories', 'accessoriesbr', 'accessoriessku', 'accidents', 'accmart', 'accommodates', 'accounts', 'accours', 'accuflora', 'aceite', 'aceites', 'acetamidopropyl', 'aches', 'achievebrour', 'achieving', 'acids', 'acnecausing', 'acnegone', 'acneprone', 'acnesmooths', 'acolorsecondary', 'acqua', 'acrylates', 'acrylicbr', 'acrylicbrpackage', 'acrylics', 'acryloyldimethyl', 'actions', 'activated', 'activates', 'actives', 'activities', 'actualnbsp', 'acure', 'adams', 'adapted', 'adapterbr', 'adapters', 'adapts', 'addictive', 'adding', 'additioned', 'additives', 'addresses', 'adds', 'adheres', 'adhering', 'adhesives', 'adiv', 'adjustablebr', 'adjusted', 'adjustments', 'adjusts', 'adm', 'adorned', 'adrenalinequot', 'ads', 'adults', 'adultsbr', 'advances', 'advantages', 'adventures', 'advisedthis', 'af', 'affects', 'affiliated', 'affinitic', 'afflictions', 'africa', 'afro', 'afrostyle', 'afterbath', 'aftercleansing', 'aftermarket', 'aftershave', 'afterwardsbr', 'ag', 'agarwood', 'agedefense', 'agefighting', 'ageing', 'agente', 'agents', 'agereversing', 'ages', 'agesbr', 'aggressivequot', 'aggressors', 'ahas', 'ahc', 'ahrong', 'aidan', 'aiding', 'aids', 'ailments', 'ailmentsbrbr', 'aims', 'airbrnbsp', 'airbrushed', 'airbrushes', 'airfloss', 'airportfriendly', 'airrelease', 'airsense', 'airtite', 'airways', 'aisila', 'akak', 'akoak', 'alagio', 'alcoholfree', 'alfaparf', 'algenist', 'alguronic', 'ali', 'aliceva', 'aligning', 'alkalizing', 'allbr', 'allday', 'allegresse', 'allens', 'allergens', 'allergies', 'allergytestedbr', 'allimportant', 'allinone', 'allnatural', 'allnew', 'allocated', 'allout', 'allowed', 'allowing', 'allows', 'alloybr', 'alloybrbrsize', 'alloynbsp', 'allpurpose', 'allvegetable', 'allveggie', 'allway', 'almay', 'almondamarettoanise', 'almonds', 'aloetherapy', 'aloha', 'alphahydroxyl', 'alreadypierced', 'altamy', 'altclean', 'alterna', 'alternifolia', 'alters', 'alteya', 'altfloss', 'altima', 'altimprove', 'altold', 'altpaste', 'altproduct', 'altreduce', 'altremove', 'altwaterpik', 'aluminumfree', 'amaretto', 'amazons', 'ambre', 'americans', 'americas', 'amgood', 'aminomethyl', 'amira', 'amisa', 'amlactin', 'ammoniafree', 'amore', 'amounts', 'amp', 'amplified', 'anc', 'andalou', 'andbody', 'andbrphysiological', 'andis', 'andnbsp', 'andtowels', 'anessa', 'angelaicos', 'angelsbr', 'anglesbr', 'angustifolia', 'anillos', 'animales', 'animals', 'animalsbr', 'aniston', 'anleolife', 'annoyed', 'annuus', 'anointing', 'anself', 'ansi', 'ansikt', 'antagonists', 'antiacne', 'antiage', 'antiageing', 'antiaging', 'antibacteria', 'antibacterialbr', 'antibiotics', 'antiblemish', 'antibump', 'anticavity', 'antidandruff', 'antidust', 'antielectrostatic', 'antievil', 'antifog', 'antifrizz', 'antifungal', 'antiinflammatories', 'antiinflammatory', 'antiitch', 'antimicrobial', 'antimonkey', 'antinausea', 'antioxidantrich', 'antioxidants', 'antipasto', 'antiperpirant', 'antiperspirant', 'antipuff', 'antipuffiness', 'antiscald', 'antiseptics', 'antishine', 'antisilver', 'antisnoring', 'antispot', 'antistain', 'antistatic', 'antistress', 'antiwrinkle', 'anusol', 'anveinao', 'anymore', 'anytime', 'aoful', 'apeel', 'aperfect', 'aplicacin', 'aplus', 'aplusmedia', 'app', 'apparels', 'appears', 'appearus', 'applehorehoundkeokekey', 'apples', 'appliances', 'applicationbr', 'applicationmoisten', 'applications', 'applicationsgreat', 'applicatorbrbrbr', 'applicators', 'applicatorsbr', 'applies', 'applybr', 'applying', 'appreciated', 'approved', 'approx', 'approximations', 'aq', 'aquaphor', 'aquatics', 'aquis', 'arabica', 'arax', 'arcbr', 'archeological', 'archydil', 'ardell', 'areas', 'areathe', 'areathis', 'argan', 'aris', 'aristata', 'aritaum', 'arkopharma', 'armaf', 'ar ...

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer().fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(ratings_metadata['unstructured'], 20)
df1 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df1.groupby('unstructured').sum()['count'].sort_values() #.iplot(kind='barh', yTitle='Count', linecolor='black', title='Top 20 words in product description before removing stop words')
# Out:
# unstructured
# face         271
# size         278
# black        301
# amp          319
# nail         338
# cream        339
# pack         384
# color        412
# body         438
# natural      454
# use          463
# oil          513
# oz           577
# category     816
# hair         955
# br          1198
# skin        1227
# personal    2488
# beauty      2606
# care        2669
# Name: count, dtype: int64

# %%
def get_top_n_words(corpus, n=None):
    vec = CountVectorizer(stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_words(ratings_metadata['unstructured'], 20)
df2 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df2.groupby('unstructured').sum()['count'].sort_values()
# Out:
# unstructured
# face         271
# size         278
# black        301
# amp          319
# nail         338
# cream        339
# pack         384
# color        412
# body         438
# natural      454
# use          463
# oil          513
# oz           577
# category     816
# hair         955
# br          1198
# skin        1227
# personal    2488
# beauty      2606
# care        2669
# Name: count, dtype: int64

# %% [markdown]
# Bigrams Frequency Distribution Removing Stop Words

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(ratings_metadata['unstructured'], 20)
df3 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df3.groupby('unstructured').sum()['count'].sort_values(ascending=False)
# Out:
# unstructured
# personal care      2464
# beauty personal    2458
# category beauty     594
# br br               189
# fl oz               117
# shea butter          81
# oz pack              76
# nail art             74
# high quality         64
# pack category        61
# skin types           57
# nail polish          51
# br beauty            50
# skin care            49
# aloe vera            47
# brand new            43
# top coat             42
# tea tree             42
# dry skin             41
# made usa             41
# Name: count, dtype: int64

# %%
def get_top_n_bigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(2, 2), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_bigram(ratings_metadata['unstructured'], 20)
df4 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df4.groupby('unstructured').sum()['count'].sort_values(ascending=False)
# Out:
# unstructured
# personal care      2464
# beauty personal    2458
# category beauty     594
# br br               190
# fl oz               117
# shea butter          81
# oz pack              76
# nail art             74
# high quality         64
# pack category        61
# skin types           57
# nail polish          51
# br beauty            50
# skin care            49
# aloe vera            47
# brand new            43
# tea tree             42
# dry skin             41
# essential oil        40
# essential oils       39
# Name: count, dtype: int64

# %% [markdown]
# Trigrams Frequency Distribution Removing Stop Words

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3)).fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(ratings_metadata['unstructured'], 20)
df5 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df5.groupby('unstructured').sum()['count'].sort_values(ascending=False)
# Out:
# unstructured
# beauty personal care                    2458
# category beauty personal                 594
# br beauty personal                        49
# oz beauty personal                        35
# pack category beauty                      32
# pack beauty personal                      30
# skin beauty personal                      26
# mmediaamazoncom images aplusmedia         24
# images aplusmedia mg                      24
# packed safely bubble                      23
# retail box packed                         23
# box packed safely                         23
# usa beauty personal                       23
# oz pack category                          22
# imagesnasslimagesamazoncom images 01      22
# tea tree oil                              21
# oz category beauty                        19
# package beauty personal                   18
# butter cocoa butter                       18
# brno retail box                           18
# Name: count, dtype: int64

# %%
def get_top_n_trigram(corpus, n=None):
    vec = CountVectorizer(ngram_range=(3, 3), stop_words='english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]
common_words = get_top_n_trigram(ratings_metadata['unstructured'], 20)
df6 = pd.DataFrame(common_words, columns = ['unstructured' , 'count'])
df6.groupby('unstructured').sum()['count'].sort_values(ascending=False)
# Out:
# unstructured
# beauty personal care                    2458
# category beauty personal                 594
# br beauty personal                        49
# oz beauty personal                        35
# pack category beauty                      32
# pack beauty personal                      30
# skin beauty personal                      26
# usa beauty personal                       26
# mmediaamazoncom images aplusmedia         24
# images aplusmedia mg                      24
# packed safely bubble                      23
# retail box packed                         23
# box packed safely                         23
# oz pack category                          22
# imagesnasslimagesamazoncom images 01      22
# tea tree oil                              21
# oz category beauty                        19
# package beauty personal                   18
# brno retail box                           18
# br br br                                  18
# Name: count, dtype: int64

# %% [markdown]
# ## 產生推薦

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# 計算商品用標題所表示的 tfidf 矩陣
# ngram_range=(1, 3) -> ngram_range=(1, 1)
df = ratings_metadata.drop_duplicates('unstructured')
for unusual_words in unusual:
  df['unstructured'] = df['unstructured'].replace(unusual_words, '')
tf = TfidfVectorizer(analyzer='word', ngram_range=(1, 1), min_df=0, stop_words='english')
tfidf_matrix = tf.fit_transform(df['unstructured'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(df['unstructured'])
vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '00020', ..., 'zwzcyz', 'zzzrt', 'zzzsafter'],
#       dtype=object)

# %%
# 計算商品間的相似程度
# cosine_similarity
from sklearn.metrics.pairwise import cosine_similarity
similarity_matrix = cosine_similarity(tfidf_matrix)
mapping = pd.Series(df.index,index = df['unstructured'])

# %%
# 每個商品回傳 k 個最相近的商品
def recommend_item(item_input, k=2):
    try:
        item_index = mapping[item_input]
        similarity_score = list(enumerate(similarity_matrix[item_index]))
        similarity_score = sorted(similarity_score, key=lambda x: x[1], reverse=True)
        similarity_score = similarity_score[:k]
        item_indices = [i[0] for i in similarity_score]
        return (df['asin'].iloc[item_indices].tolist())
    except:
        return []

# 利用使用者購買過的商品產生推薦
def recommend_items(items, k):
    res = []
    for d in items:
        res.extend(recommend_item(d, k))
    return res

# %%
def recommender(training_data, users=[], k=10):
    '''
    * training_data: dataframe 輸入的訓練資料集（2018-09-01 以前資料）
    * users: [] 需要被推薦的使用者
    * k: int 每個使用者需要推薦的商品數
    * recommendations: dict
      {
          使用者一： [推薦商品一, 推薦商品二, ...],
          使用者二： [...], ...
      }
    '''
    recommendations = {}
    '''
    content-based
    '''
    ratings_trainings = training_data
    for user in users:

        # content based
        content_list = recommend_items(ratings_metadata[ratings_metadata['asin'].isin(ratings_trainings[ratings_trainings['reviewerID'] == user]['asin'].tolist())]['asin'].tolist(), k)
        if content_list:
            recommendations[user] = content_list
        else:
            # rule based
            recommendations[user] = ratings_metadata.asin[:k].tolist()

    # recommendations = {user: recommend_items(ratings_metadata[ratings_metadata['asin'].isin(ratings_trainings[ratings_trainings['reviewerID'] == user]['asin'].tolist())]['unstructured'].tolist(), k) for user in users}
    
    return recommendations

ratings_by_user = recommender(ratings_trainings, users)
ratings_by_user
# Out:
# {'A100XQFWKQ30O2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A103T1QOGFCSEH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A106UKKSJ2KXPF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A10A7GV4D5A11V': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1119JJ37ZLB8R': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A113UOOLBSZN52': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A12M4U7WK4ALCR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A12T8YTW6VWT7S': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1364JXGKB46MM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A137DALOQFKBTI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13FEZ3WV7S2EY': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13IV4I1B0RXMG': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13JU88JAHN72I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13K55R6VH1OOD': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13P7VFU075A': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13SWYE4QLB6NG': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A13ZTQ0Q4ATA41': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A142EDN04OD62U': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A142I22FIC8MZK': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14834QTII5TLT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14A447VPACTBC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14AP6MN5XO6LB': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14CLF25IX25US': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14LYXC3HTBAHI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14VUW4KZ34EOE': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A14Y32P26G9YL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A157T25PBS7MX4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A15HZDSERD85C8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A15JJ8J1FGADIX': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A15ZCL70JXXH89': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1617KN2IAWZ6J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A16E0O88262HKA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A16NSZ58PTVIYF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A16UGDXRTDLJG5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A16X9HR3UFQQXY': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A16Y7V1CZCWKFV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A174YOBOSW9WDN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1786SKRAJXH86': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A17K2BUZ20WD2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A17LYRFV645L0V': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A18LNGVXDZBTUR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19503XX7GU6J2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19HVHRZDYFEOP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19JM38B861BO4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19KGY3W1P0MHT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19KJPOF3QOJ24': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A19U5RT4Q8Q1T6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1AQNQUNX8B6JT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ARU0IN6RUFFD': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1BB4635KSKDMV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1BCC7X6KRTBG0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1BPJ56BXENC7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1C0RI6W65FC8B': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1C60LJGZVEK27': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1CB2SMS3TD44Z': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1CNSU8P68CPLT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1CSDWBYUJBCJZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1CTNNVIYHO25P': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1CTQF97HFYOZB': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1D5C2H9UFZHPU': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1D5UVH72Z6NJ1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1DAUVZRVSLLNW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1DCZ9882PXLVB': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1DZ63D35BNT86': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1E0QCKB4R2X8X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1E76OZZ5YUWVA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1EBHZPAYMILW9': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1EJVNGBY5GM5I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ER0356V2DSKW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1EY751AUVO5NZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1EZFX1TRHSAJX': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1F08GM4B97FV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1F6EFMBK795DJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1FC8Y896NZP4T': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1FKIAKVOBNN7Y': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1FKUBRPLG6Y8I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1G2HL4W8B3TA0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1G8Z9IKJ0BD1M': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1GEJ55RJGD7JW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1GIYGD23YIDTN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1GLG2IZBZHRAJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1H1T82FPO20DN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1H7JDZ9BKTKGC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1HBROZPSV5KT6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1HBXMUIHTAIU2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1I32A4SA9W2L2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1IDJ6KR8CQV9I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1II0TTUUE2C7Y': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ILEZFIVOU0EP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ITJ5M7I9G7FR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1IWTXM1SJWHDN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1J2NTTE63GNG2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1JRREJ5D62LFF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1KGMTEXL70WF6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1KWUQZJ1Z6MN2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1LXJ8XCGNBXOF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1M8YMS915ZK0B': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1NDRR3G9SJF18': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1NE6K8PXW780O': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1NEG0FRW5FDBL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1NN82RWB6PXJW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1NY67EVWD6CD6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1OB41VQHXZ0R8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1OJ2IXX8F7Q7X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1OTIUDE7LWAGT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1P1OHYJOOZX5P': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1PFDA9SL15S4O': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1PKBKALGLSX0Z': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1PMLXHE863GR6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1PR178735XC70': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1PXO67EUM5HJQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1QHS58JVFLF3I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1QPKRHCAOQVZ5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1R2TTULP0Z2BM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1R8GBYBJWWWU0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1RAXJN2Q4V20X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1RCMCAJR2LJA4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1RE2XA5HQD1D3': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1RMLPJ1PF8LGV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1RX2ODQRQZVSI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1S3NMNTSO6GW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1S6OQV823B53J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1SA3N793WT2LM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1SA932MLERVQY': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1SCZBXGPJ2615': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1SMXRCNRO4ZQM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1T1N2585E1T0D': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TEKLMF4V1X2C': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TF44D9KYAD60': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TGP1VTM3KCTI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TK5M6EM3GS3C': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TO3GV14TGF2R': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1TP9JHTIY468V': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1UAOE8KO7Q1DZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1UDCDY6ZNE83T': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1UUNKRU1DTZTL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1V0UJQ4XGAJ3H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1VBZLO2JGYU1B': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1VC6YCAFKV6Q': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1VVEX78B2TYBX': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1VVQ2DFL0QLXF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1VYWSQ2OXLH98': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1WEFBEJ7OHSVZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1WOX40GUAFDKW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1WSZED2O5MA5T': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1XBJBT6HORBLA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1XHN6JF8A8W69': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1XWCTARAQ0679': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1XZJ85PKMAZP0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YALF6PWOMS6S': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YEO5KEW7M2GF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YQ33635DJEG5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YSAFP6T3JZ1C': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YTPCNXQ2LJ5Z': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1YVXZK51DEDPC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1Z3GE09RDY6O7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1Z6IPI0G3QIUR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ZVXL7K0XY3S6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A1ZXYITUZM3Q6A': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A202BVEB76NTMK': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A205S0BTPEFI0I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A20MSUD02BETH2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A20P2XESU3G3EC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A20QY357E6SAF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A20SJ2793OUCPW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A20T7NNNUHH60H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21JL9NVA7KEMC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21M4N08F3EU5J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21NUBJVBS230S': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21OELUKDF2E57': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21XQP90LEND9R': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A21YO11OY4KATO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A220EHDBIGBL30': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A224YJVNU30DVM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A22A1B25VBD0YO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A22EWIMT2GUTTL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A22EZJLTPINCFS': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A22QJRB86RF6O1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2320AUCHA95U2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A232IJ75I4KP9C': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A23GTKDW92ZPP2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A23O1B8IVSYKMO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A23VR3KT0TPG83': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A24HCM5QV0ZTJ5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A24ZE4O3OQMSP0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A255E6ZWUBMEJJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A258D00BRNHJ77': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A25TLD8KIU807H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A26434CRUTADT5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A26AT96096UOEZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A26RKZDM4DK8OQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A274IW68565M0U': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A286OWYO1BDT52': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A288UAQLON8FK2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28E3FNV1BYC94': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28GO11F387SOX': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28H0PFALTML0I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28OZKV4ZYZX42': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28P7FF1TVPG1K': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A28Q7C1FAIZGLV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A29834GBB4DOP1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A29HQ60YC1RG1P': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A29MENRU87PET0': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A29PZKXDCQFTYW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A29SD3TFGX6Q34': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2A0MIOWIW2SB8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2A8ECI6ABJBMA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2AAQWBJJTK3E1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2AE0E0H463YL6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2APG6OZXU4QIZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2BDB427ROEP7H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2BHJO8WOGMW6E': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2BOSA30FCF6G8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2BU6N5956T9NH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2BUZ308P92OYA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2C1F859F9V1SL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2C8YINPNRQOAU': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2CDQOF7WHUYKJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2CEEE0IK3LKN1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2CZVE6ORV87C5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2DD6RH1AF0PLI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2DFOCWUKJX3PT': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2E8WG5GRZGMXU': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2ESQAPIGR2TJF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2EUQ4ESAB2N6A': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2EZXF5YGYTOWN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2F0VQQLSF558D': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2F3QV40SONN60': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2F95NSPD4XEEU': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2FA2J1JT12N7J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2FFUJ5D4CMJ4L': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2FLLYV6Z8UQ26': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2G1XJ25DR7PVF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2G5KJ0CZE65ZD': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2GFPTQ4VWDX96': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2GJLNRQTVUNOF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2GOFJ3OZZUZ3H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2GV0FE30O6M67': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2H3W11661MWDA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2H7FD5GQMJXAQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2H7VSYLKGKLLJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2HFAX39PMLIGH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2I4O72AAE1T1T': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2I868XUY96VWA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2IK039KMC8UP1': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2IMJV0CQMZLGC': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2INWR0T7A7UN5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2IOBG1ERS4JP3': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2IRPQ7DXQ9YIN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2J4WOR87ELFBH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2JCBLTLYDPQLW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2JEH2NKM1Z8CQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2JXZSR7R85KX4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2K7XZCFYGZH0O': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2KO4HGLWB57LI': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2KVN4XKFJH0I8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2LM47GK1W7RRR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2LSOMD2X9KCCH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2LYTBRWFQJMKM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2M4YSOJZELJ6N': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2MAZK8XSIDXPF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2MDIPJ7MS0MUJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2MGO3WV3SX7X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2MLV3I5MMJ2RA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2MPSHMC0U29AV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2NI47L1B1RXSG': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2NJQZBE8TSUYO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2NWTETCSLOEQN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'A2O4DMC8M5JFHG': ['B01DKQAXC0',
# ...
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AD9O852KPYLHY': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ADDXT6NXD9GQ7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ADG8D8X6P9X7M': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ADR4IE33O06IJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ADV1MNMPVS17V': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ADYRHTPM2T2SE': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AE6VHWVRXHU19': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AEKJTREHL41OE': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AEP7KPEZWI7VY': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AETOYW0R5VN0X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AEZBSOFLB44RG': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AFE9H6ABXM735': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AFMQ7BBR4FYMB': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AFY8EIWAT6H8J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AG0867QGE3R2B': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AG3T3ILPXFL3H': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AG74ZKO3BG57J': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AGORXWI6K2RIR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AGRZQOBCF8H87': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AGTD0T9R78YLG': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AGYIYIVZHBI60': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AHGNU4UWGATOH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AHYRXYR235TWH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AIB7HX2UC3WHM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AITF34BGBMVJJ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AIU7HYQIC5D95': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AJHSB0LT8NKP4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AJYMJEC6B7V52': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AK4VANLR5UK95': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AK7YIZE6ZZ1N9': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AKHSKD91MQ9DP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ALUZH689LQE6K': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ALWLZC3GRRXPN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AM1KUDVTKXIAQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AM9HBLGAPZQR7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AMA98TY969A1T': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AMLDY4QY4HV0D': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AMVZ9HW23Y42N': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AN3QZR3OD7SFO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANC6FN6T8JBB2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANDGVKQ15NCZM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANFUWUOC7EJKR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANG7MOYBTWQE6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANJ6Y9G0B4TM8': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANR73TPVBCQ9K': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ANT034IX5ZPI9': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AOB2Y1KJQG7K7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AONHG4PDUQ0D6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'APA9SALOTTBM6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'APARJQGAD0J4C': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AQ5PKYF0FJA4B': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AQCQQYEUHUX3M': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AQYL4TDY2HU8Z': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AR9Y0CM5B174': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ARLN791TA1RV7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AS8T77HTF9IHW': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ASGIVOW34XNQS': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ATJRZUXNWAWIK': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ATP2UCHTR7QMZ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ATR9J7TYR1KVL': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'ATVP6QJLS27EN': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AU03W1V42994X': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AU1BVXGV2KO8I': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AU2JWZMFEVAH5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AU3MVNMVFSIM': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AUKMWTDK16PAP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AUWJT1DM7SG2D': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AV0O5NWF2NKDF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AV2MC7NNTMKTF': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVC89473DX6XU': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVFBQDR2KRNK6': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVIMJH2FF6QCH': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVO5FL5T9EZSR': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVQ0V2MIW2Z5K': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AVWSUUBWD3RK4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AWJFUVK3064HX': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AXM9OKKHRR4RP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AXPZI9N8HVHYO': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AXQ57AZLKLPCQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AXQS1B3WVRHQV': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AXS7NH3GDN7EE': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AY4F95T0JSTZ2': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AYG63OK9TNBNP': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZE64W03EUJA4': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZECTAHZICNW5': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZEGZXCFTLSQB': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZEKC7DEXXJD7': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZFGSCB0S59LQ': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0'],
#  'AZHS42HV4FKKA': ['B01DKQAXC0',
#   'B00W259T7G',
#   'B012Z7IHHI',
#   'B013XKHA4M',
#   'B0195R1FT8',
#   'B01AVJCDYA',
#   'B006IB5T4W',
#   'B00JVU3K9I',
#   'B01CJNZKZK',
#   'B0168SXRR0']}

# %% [markdown]
# ## 結果評估

# %%
def evaluate(ratings_testings_by_user={}, ratings_by_user={}, method=None):
    '''
    * ratings_testings_by_user: dict 真實被購買的商品資料（2018-09-01 以後資料）
    * ratings_by_user: dict 利用訓練資料學習的推薦商品
    * method: str
    * score: float
    '''
    total = 0
    for d in ratings_testings_by_user:
        if d in ratings_by_user:
            total += len(set(ratings_by_user[d]) & set(ratings_testings_by_user[d]))

    score = total / len(ratings_testings)
    return score

evaluate(ratings_testings_by_user, ratings_by_user) 

# random 0.003389830508474576
# rule-based 0.013559322033898305
# rule based + content based 0.098
# rule based + content (只抽取一個單字) 0.13389830508474576
# 觀察到title vs title + description+ ...的結果一樣
# Out:
# 0.13389830508474576

# %%
# reference https://towardsdatascience.com/building-a-content-based-recommender-system-for-hotels-in-seattle-d724f0a32070

# %%
def recommender_rule(training_data, users=[], k=10):
    '''
    * training_data: dataframe 輸入的訓練資料集（2018-09-01 以前資料）
    * users: [] 需要被推薦的使用者
    * k: int 每個使用者需要推薦的商品數
    * recommendations: dict
      {
          使用者一： [推薦商品一, 推薦商品二, ...],
          使用者二： [...], ...
      }
    '''
    recommendations = {}
    '''
    ruled-based
    '''
    ratings_trainings = training_data
    product_df = ratings_trainings[['asin', 'product_score', 'product_popularity', 'avg_review']].drop_duplicates()
    avg_brandLoyalty_df = ratings_trainings[['asin', 'avg_brandLoyalty']].drop_duplicates()

    for user in users:
      # choose top 2 brands for user
      brand_list = []
      if len(ratings_trainings[ratings_trainings['reviewerID'] == user]["brand_loyalty"]) > 0:
        index = ratings_trainings[ratings_trainings['reviewerID'] == user]["brand_loyalty"].nlargest(2).index
      else:
        index = avg_brandLoyalty_df["avg_brandLoyalty"].nlargest(5).index

      for id in index:
        brand_list.append(ratings_trainings['brand_filled'][id])
      brand_list = list(dict.fromkeys(brand_list))

      product_list = []
      for brand in brand_list:
        prod_list = ratings_trainings[ratings_trainings['brand_filled'] == brand]['asin'].tolist()
        prod_list = list(dict.fromkeys(prod_list))
        product_list.append(prod_list)
      product_list = list(chain(*product_list))

      # product_score / avg_review / product_popularity
      top25_by_productScore = product_df[product_df['asin'].isin(product_list)].nlargest(25, "product_score")
      top15_by_avgReview = top25_by_productScore.nlargest(15, "avg_review")
      if len(top15_by_avgReview.asin) >= 10:
        # bottom = top15_by_avgReview.nsmallest(5, "product_popularity")['asin'].tolist()
        top = top15_by_avgReview.nlargest(10, "product_popularity")['asin'].tolist()
        recommendation = top
      else:
        sample = len(top15_by_avgReview.asin)
        random_sample = 10 - len(top15_by_avgReview.asin)
        bottom = top15_by_avgReview.nsmallest(sample, "product_popularity")['asin'].tolist()
        top = product_df['asin'].sample(n=random_sample).tolist()
        recommendation = bottom + top
      recommendations[user] = recommendation

    return recommendations
